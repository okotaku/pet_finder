# %%
import feather
import scipy as sp
import numpy as np
import pandas as pd
import lightgbm as lgb

from collections import Counter
from functools import partial
from math import sqrt
from scipy.stats import rankdata

from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.metrics import confusion_matrix as sk_cmatrix
from sklearn.model_selection import StratifiedKFold, GroupKFold

import matplotlib.pyplot as plt
import seaborn as sns

def get_score(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def get_y():
    return pd.read_csv('../input/petfinder-adoption-prediction/train/train.csv', usecols=[target]).values.flatten()
    
def run_model(X_train, y_train, X_valid, y_valid, X_test,
            categorical_features, numerical_features,
            predictors, maxvalue_dict, fold_id):
    train = lgb.Dataset(X_train, y_train, 
                        categorical_feature=categorical_features, 
                        feature_name=predictors)
    valid = lgb.Dataset(X_valid, y_valid, 
                        categorical_feature=categorical_features, 
                        feature_name=predictors)
    evals_result = {}
    model = lgb.train(
        MODEL_PARAMS,
        train,
        valid_sets=[valid],
        valid_names=['valid'],
        evals_result=evals_result,
        **FIT_PARAMS
    )
    
    # validation score
    y_pred_valid = model.predict(X_valid)
    y_pred_test = model.predict(X_test)

    return y_pred_valid, y_pred_test
 
def plot_mean_feature_importances(feature_importances, max_num=50, importance_type='gain', path=None):
    mean_gain = feature_importances[[importance_type, 'feature']].groupby('feature').mean()
    feature_importances['mean_' + importance_type] = feature_importances['feature'].map(mean_gain[importance_type])

    if path is not None:
        data = feature_importances.sort_values('mean_'+importance_type, ascending=False).iloc[:max_num, :]
        plt.clf()
        plt.figure(figsize=(16, 8))
        sns.barplot(x=importance_type, y='feature', data=data)
        plt.tight_layout()
        plt.savefig(path)
    
    return feature_importances

def to_bins(x, borders):
    for i in range(len(borders)):
        if x <= borders[i]:
            return i
    return len(borders)

class OptimizedRounder_(object):
    def __init__(self):
        self.coef_ = 0

    def _loss(self, coef, X, y, idx):
        X_p = np.array([to_bins(pred, coef) for pred in X])
        ll = -get_score(y, X_p)
        return ll

    def fit(self, X, y):
        coef = [1.5, 2.0, 2.5, 3.0]
        golden1 = 0.618
        golden2 = 1 - golden1
        ab_start = [(1, 2), (1.5, 2.5), (2, 3), (2.5, 3.5)]
        for it1 in range(10):
            for idx in range(4):
                # golden section search
                a, b = ab_start[idx]
                # calc losses
                coef[idx] = a
                la = self._loss(coef, X, y, idx)
                coef[idx] = b
                lb = self._loss(coef, X, y, idx)
                for it in range(20):
                    # choose value
                    if la > lb:
                        a = b - (b - a) * golden1
                        coef[idx] = a
                        la = self._loss(coef, X, y, idx)
                    else:
                        b = b - (b - a) * golden2
                        coef[idx] = b
                        lb = self._loss(coef, X, y, idx)
        self.coef_ = {'x': coef}

    def predict(self, X, coef):
        X_p = np.array([to_bins(pred, coef) for pred in X])
        return X_p

    def coefficients(self):
        return self.coef_['x']
    
class OptimizedRounder(object):
    def __init__(self):
        self.coef_ = 0

    def _loss(self, coef, X, y, idx):
        X_p = np.array([to_bins(pred, coef) for pred in X])
        ll = -get_score(y, X_p)
        return ll

    def fit(self, X, y):
        coef = [0.2, 0.4, 0.6, 0.8]
        golden1 = 0.618
        golden2 = 1 - golden1
        ab_start = [(0.01, 0.3), (0.15, 0.56), (0.35, 0.75), (0.6, 0.9)]
        for it1 in range(10):
            for idx in range(4):
                # golden section search
                a, b = ab_start[idx]
                # calc losses
                coef[idx] = a
                la = self._loss(coef, X, y, idx)
                coef[idx] = b
                lb = self._loss(coef, X, y, idx)
                for it in range(20):
                    # choose value
                    if la > lb:
                        a = b - (b - a) * golden1
                        coef[idx] = a
                        la = self._loss(coef, X, y, idx)
                    else:
                        b = b - (b - a) * golden2
                        coef[idx] = b
                        lb = self._loss(coef, X, y, idx)
        self.coef_ = {'x': coef}

    def predict(self, X, coef):
        X_p = np.array([to_bins(pred, coef) for pred in X])
        return X_p

    def coefficients(self):
        return self.coef_['x']
    
class StratifiedGroupKFold():
    def __init__(self, n_splits=5):
        self.n_splits = n_splits
    
    def split(self, X, y=None, groups=None):
        fold = pd.DataFrame([X, y, groups]).T
        fold.columns = ['X', 'y', 'groups']
        fold['y'] = fold['y'].astype(int)
        g = fold.groupby('groups')['y'].agg('mean').reset_index()
        fold = fold.merge(g, how='left', on='groups', suffixes=('', '_mean'))
        fold['y_mean'] = fold['y_mean'].apply(np.round)
        fold['fold_id'] = 0
        for unique_y in fold['y_mean'].unique():
            mask = fold.y_mean==unique_y
            selected = fold[mask].reset_index(drop=True)
            cv = GroupKFold(n_splits=n_splits)
            for i, (train_index, valid_index) in enumerate(cv.split(range(len(selected)), y=None, groups=selected['groups'])):
                selected.loc[valid_index, 'fold_id'] = i
            fold.loc[mask, 'fold_id'] = selected['fold_id'].values
            
        for i in range(self.n_splits):
            indices = np.arange(len(fold))
            train_index = indices[fold['fold_id'] != i]
            valid_index = indices[fold['fold_id'] == i]
            yield train_index, valid_index
            
def merge(train, test, path, add_cols):
    df_ = feather.read_dataframe(path)
    add_cols += list(df_.columns)
    train = pd.concat((train, df_[:n_train]), axis=1)
    test = pd.concat((test, df_[n_train:].reset_index(drop=True)), axis=1)
    return train, test, add_cols

# %%
target = 'AdoptionSpeed'
len_train = 14993
len_test = 3948
    
    
# ===============
# Params
# ===============
seed = 777
n_splits = 5
np.random.seed(seed)

# feature engineering
n_components = 5
img_size = 256
batch_size = 256

# model
MODEL_PARAMS = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'num_leaves': 63,
    'subsample': 0.9,
    'subsample_freq': 1,
    #'colsample_bytree': 0.6,
    'max_depth': 9,
    'max_bin': 127,
    'reg_alpha': 0.11,
    'reg_lambda': 0.01,
    'min_child_weight': 0.2,
    'min_child_samples': 20,
    'min_gain_to_split': 0.02,
    'min_data_in_bin': 3,
    'bin_construct_sample_cnt': 5000,
    'cat_l2': 10,
    'verbose': -1,
    'nthread': 16,
    'seed': 777,
}
FIT_PARAMS = {
    'num_boost_round': 5000,
    'early_stopping_rounds': 100,
    'verbose_eval': 10000,
}

# define
maxvalue_dict = {}
categorical_features = [
     'Breed1',
     'Breed2',
     'Color1',
     'Color2',
     'Color3',
     'Dewormed',
     'FurLength',
     'Gender',
     'Health',
     'MaturitySize',
     'State',
     'Sterilized',
     'Type',
     'Vaccinated',
     'Type_main_breed',
     'BreedName_main_breed',
     'Type_second_breed',
     'BreedName_second_breed',
]
numerical_features = []
text_features = ['Name', 'Description']
remove = ['index', 'seq_text', 'PetID', 'Name', 'Description', 'RescuerID', 'StateName', 'annots_top_desc', 'Description_Emb']

# %%
train = feather.read_dataframe('X_trainv16.feather')
n_train = len(train)
add_cols = []

test = feather.read_dataframe('X_testv16.feather')
#---
#text feature select
#---
#train, test, add_cols = merge(train, test, "feature/quora_fasttext.feather", add_cols)
#train, test, add_cols = merge(train, test, "feature/quora_fasttext_meta.feather", add_cols)

#train, test, add_cols = merge(train, test, "feature/quora_fasttext_selftrain.feather", add_cols)
#train, test, add_cols = merge(train, test, "feature/quora_fasttext_selftrain_meta.feather", add_cols)

train, test, add_cols = merge(train, test, "feature/googlenews_mag_light.feather", add_cols)
train, test, add_cols = merge(train, test, "feature/googlenews_mag_ligh_tmeta.feather", add_cols)

#---
#image feature select
#---
train, test, add_cols = merge(train, test, "feature/inception_resnet.feather", add_cols)

# %%
add_cols
# Out:
# ['quora_fasttext1',
#  'quora_fasttext2',
#  'quora_fasttext3',
#  'quora_fasttext4',
#  'quora_fasttext5',
#  'quora_fasttext6',
#  'quora_fasttext7',
#  'quora_fasttext8',
#  'quora_fasttext9',
#  'quora_fasttext10',
#  'quora_fasttext11',
#  'quora_fasttext12',
#  'quora_fasttext13',
#  'quora_fasttext14',
#  'quora_fasttext15',
#  'quora_fasttext16',
#  'quora_fasttext17',
#  'quora_fasttext18',
#  'quora_fasttext19',
#  'quora_fasttext20',
#  'quora_fasttext21',
#  'quora_fasttext22',
#  'quora_fasttext23',
#  'quora_fasttext24',
#  'quora_fasttext25',
#  'quora_fasttext26',
#  'quora_fasttext27',
#  'quora_fasttext28',
#  'quora_fasttext29',
#  'quora_fasttext30',
#  'quora_fasttext31',
#  'quora_fasttext32',
#  'quora_fasttext33',
#  'quora_fasttext34',
#  'quora_fasttext35',
#  'quora_fasttext36',
#  'quora_fasttext37',
#  'quora_fasttext38',
#  'quora_fasttext39',
#  'quora_fasttext40',
#  'quora_fasttext41',
#  'quora_fasttext42',
#  'quora_fasttext43',
#  'quora_fasttext44',
#  'quora_fasttext45',
#  'quora_fasttext46',
#  'quora_fasttext47',
#  'quora_fasttext48',
#  'quora_fasttext49',
#  'quora_fasttext50',
#  'quora_fasttext51',
#  'quora_fasttext52',
#  'quora_fasttext53',
#  'quora_fasttext54',
#  'quora_fasttext55',
#  'quora_fasttext56',
#  'quora_fasttext57',
#  'quora_fasttext58',
#  'quora_fasttext59',
#  'quora_fasttext60',
#  'quora_fasttext61',
#  'quora_fasttext62',
#  'quora_fasttext63',
#  'quora_fasttext64',
#  'quora_fasttext65',
#  'quora_fasttext66',
#  'quora_fasttext67',
#  'quora_fasttext68',
#  'quora_fasttext69',
#  'quora_fasttext70',
#  'quora_fasttext71',
#  'quora_fasttext72',
#  'quora_fasttext73',
#  'quora_fasttext74',
#  'quora_fasttext75',
#  'quora_fasttext76',
#  'quora_fasttext77',
#  'quora_fasttext78',
#  'quora_fasttext79',
#  'quora_fasttext80',
#  'quora_fasttext81',
#  'quora_fasttext82',
#  'quora_fasttext83',
#  'quora_fasttext84',
#  'quora_fasttext85',
#  'quora_fasttext86',
#  'quora_fasttext87',
#  'quora_fasttext88',
#  'quora_fasttext89',
#  'quora_fasttext90',
#  'quora_fasttext91',
#  'quora_fasttext92',
#  'quora_fasttext93',
#  'quora_fasttext94',
#  'quora_fasttext95',
#  'quora_fasttext96',
#  'quora_fasttext97',
#  'quora_fasttext98',
#  'quora_fasttext99',
#  'quora_fasttext100',
#  'quora_fasttext101',
#  'quora_fasttext102',
#  'quora_fasttext103',
#  'quora_fasttext104',
#  'quora_fasttext105',
#  'quora_fasttext106',
#  'quora_fasttext107',
#  'quora_fasttext108',
#  'quora_fasttext109',
#  'quora_fasttext110',
#  'quora_fasttext111',
#  'quora_fasttext112',
#  'quora_fasttext113',
#  'quora_fasttext114',
#  'quora_fasttext115',
#  'quora_fasttext116',
#  'quora_fasttext117',
#  'quora_fasttext118',
#  'quora_fasttext119',
#  'quora_fasttext120',
#  'quora_fasttext121',
#  'quora_fasttext122',
#  'quora_fasttext123',
#  'quora_fasttext124',
#  'quora_fasttext125',
#  'quora_fasttext126',
#  'quora_fasttext127',
#  'quora_fasttext128',
#  'quora_fasttext129',
#  'quora_fasttext130',
#  'quora_fasttext131',
#  'quora_fasttext132',
#  'quora_fasttext133',
#  'quora_fasttext134',
#  'quora_fasttext135',
#  'quora_fasttext136',
#  'quora_fasttext137',
#  'quora_fasttext138',
#  'quora_fasttext139',
#  'quora_fasttext140',
#  'quora_fasttext141',
#  'quora_fasttext142',
#  'quora_fasttext143',
#  'quora_fasttext144',
#  'quora_fasttext145',
#  'quora_fasttext146',
#  'quora_fasttext147',
#  'quora_fasttext148',
#  'quora_fasttext149',
#  'quora_fasttext150',
#  'quora_fasttext151',
#  'quora_fasttext152',
#  'quora_fasttext153',
#  'quora_fasttext154',
#  'quora_fasttext155',
#  'quora_fasttext156',
#  'quora_fasttext157',
#  'quora_fasttext158',
#  'quora_fasttext159',
#  'quora_fasttext160',
#  'quora_fasttext161',
#  'quora_fasttext162',
#  'quora_fasttext163',
#  'quora_fasttext164',
#  'quora_fasttext165',
#  'quora_fasttext166',
#  'quora_fasttext167',
#  'quora_fasttext168',
#  'quora_fasttext169',
#  'quora_fasttext170',
#  'quora_fasttext171',
#  'quora_fasttext172',
#  'quora_fasttext173',
#  'quora_fasttext174',
#  'quora_fasttext175',
#  'quora_fasttext176',
#  'quora_fasttext177',
#  'quora_fasttext178',
#  'quora_fasttext179',
#  'quora_fasttext180',
#  'quora_fasttext181',
#  'quora_fasttext182',
#  'quora_fasttext183',
#  'quora_fasttext184',
#  'quora_fasttext185',
#  'quora_fasttext186',
#  'quora_fasttext187',
#  'quora_fasttext188',
#  'quora_fasttext189',
#  'quora_fasttext190',
#  'quora_fasttext191',
#  'quora_fasttext192',
#  'quora_fasttext193',
#  'quora_fasttext194',
#  'quora_fasttext195',
#  'quora_fasttext196',
#  'quora_fasttext197',
#  'quora_fasttext198',
#  'quora_fasttext199',
#  'quora_fasttext200',
#  'quora_fasttext201',
#  'quora_fasttext202',
#  'quora_fasttext203',
#  'quora_fasttext204',
#  'quora_fasttext205',
#  'quora_fasttext206',
#  'quora_fasttext207',
#  'quora_fasttext208',
#  'quora_fasttext209',
#  'quora_fasttext210',
#  'quora_fasttext211',
#  'quora_fasttext212',
#  'quora_fasttext213',
#  'quora_fasttext214',
#  'quora_fasttext215',
#  'quora_fasttext216',
#  'quora_fasttext217',
#  'quora_fasttext218',
#  'quora_fasttext219',
#  'quora_fasttext220',
#  'quora_fasttext221',
#  'quora_fasttext222',
#  'quora_fasttext223',
#  'quora_fasttext224',
#  'quora_fasttext225',
#  'quora_fasttext226',
#  'quora_fasttext227',
#  'quora_fasttext228',
#  'quora_fasttext229',
#  'quora_fasttext230',
#  'quora_fasttext231',
#  'quora_fasttext232',
#  'quora_fasttext233',
#  'quora_fasttext234',
#  'quora_fasttext235',
#  'quora_fasttext236',
#  'quora_fasttext237',
#  'quora_fasttext238',
#  'quora_fasttext239',
#  'quora_fasttext240',
#  'quora_fasttext241',
#  'quora_fasttext242',
#  'quora_fasttext243',
#  'quora_fasttext244',
#  'quora_fasttext245',
#  'quora_fasttext246',
#  'quora_fasttext247',
#  'quora_fasttext248',
#  'quora_fasttext249',
#  'quora_fasttext250',
#  'quora_fasttext251',
#  'quora_fasttext252',
#  'quora_fasttext253',
#  'quora_fasttext254',
#  'quora_fasttext255',
#  'quora_fasttext256',
#  'quora_fasttext257',
#  'quora_fasttext258',
#  'quora_fasttext259',
#  'quora_fasttext260',
#  'quora_fasttext261',
#  'quora_fasttext262',
#  'quora_fasttext263',
#  'quora_fasttext264',
#  'quora_fasttext265',
#  'quora_fasttext266',
#  'quora_fasttext267',
#  'quora_fasttext268',
#  'quora_fasttext269',
#  'quora_fasttext270',
#  'quora_fasttext271',
#  'quora_fasttext272',
#  'quora_fasttext273',
#  'quora_fasttext274',
#  'quora_fasttext275',
#  'quora_fasttext276',
#  'quora_fasttext277',
#  'quora_fasttext278',
#  'quora_fasttext279',
#  'quora_fasttext280',
#  'quora_fasttext281',
#  'quora_fasttext282',
#  'quora_fasttext283',
#  'quora_fasttext284',
#  'quora_fasttext285',
#  'quora_fasttext286',
#  'quora_fasttext287',
#  'quora_fasttext288',
#  'quora_fasttext289',
#  'quora_fasttext290',
#  'quora_fasttext291',
#  'quora_fasttext292',
#  'quora_fasttext293',
#  'quora_fasttext294',
#  'quora_fasttext295',
#  'quora_fasttext296',
#  'quora_fasttext297',
#  'quora_fasttext298',
#  'quora_fasttext299',
#  'quora_fasttext300',
#  'quora_fasttext_meta1',
#  'quora_fasttext_meta2',
#  'quora_fasttext_meta3',
#  'quora_fasttext_meta4',
#  'quora_fasttext_meta5',
#  'quora_fasttext_meta6',
#  'quora_fasttext_meta7',
#  'quora_fasttext_meta8',
#  'quora_fasttext_meta9',
#  'quora_fasttext_meta10',
#  'quora_fasttext_meta11',
#  'quora_fasttext_meta12',
#  'quora_fasttext_meta13',
#  'quora_fasttext_meta14',
#  'quora_fasttext_meta15',
#  'quora_fasttext_meta16',
#  'quora_fasttext_meta17',
#  'quora_fasttext_meta18',
#  'quora_fasttext_meta19',
#  'quora_fasttext_meta20',
#  'quora_fasttext_meta21',
#  'quora_fasttext_meta22',
#  'quora_fasttext_meta23',
#  'quora_fasttext_meta24',
#  'quora_fasttext_meta25',
#  'quora_fasttext_meta26',
#  'quora_fasttext_meta27',
#  'quora_fasttext_meta28',
#  'quora_fasttext_meta29',
#  'quora_fasttext_meta30',
#  'quora_fasttext_meta31',
#  'quora_fasttext_meta32',
#  'quora_fasttext_meta33',
#  'quora_fasttext_meta34',
#  'quora_fasttext_meta35',
#  'quora_fasttext_meta36',
#  'quora_fasttext_meta37',
#  'quora_fasttext_meta38',
#  'quora_fasttext_meta39',
#  'quora_fasttext_meta40',
#  'quora_fasttext_meta41',
#  'quora_fasttext_meta42',
#  'quora_fasttext_meta43',
#  'quora_fasttext_meta44',
#  'quora_fasttext_meta45',
#  'quora_fasttext_meta46',
#  'quora_fasttext_meta47',
#  'quora_fasttext_meta48',
#  'quora_fasttext_meta49',
#  'quora_fasttext_meta50',
#  'quora_fasttext_meta51',
#  'quora_fasttext_meta52',
#  'quora_fasttext_meta53',
#  'quora_fasttext_meta54',
#  'quora_fasttext_meta55',
#  'quora_fasttext_meta56',
#  'quora_fasttext_meta57',
#  'quora_fasttext_meta58',
#  'quora_fasttext_meta59',
#  'quora_fasttext_meta60',
#  'quora_fasttext_meta61',
#  'quora_fasttext_meta62',
#  'quora_fasttext_meta63',
#  'quora_fasttext_meta64',
#  'quora_fasttext_meta65',
#  'quora_fasttext_meta66',
#  'quora_fasttext_meta67',
#  'quora_fasttext_meta68',
#  'quora_fasttext_meta69',
#  'quora_fasttext_meta70',
#  'quora_fasttext_meta71',
#  'quora_fasttext_meta72',
#  'quora_fasttext_meta73',
#  'quora_fasttext_meta74',
#  'quora_fasttext_meta75',
#  'quora_fasttext_meta76',
#  'quora_fasttext_meta77',
#  'quora_fasttext_meta78',
#  'quora_fasttext_meta79',
#  'quora_fasttext_meta80',
#  'quora_fasttext_meta81',
#  'quora_fasttext_meta82',
#  'quora_fasttext_meta83',
#  'quora_fasttext_meta84',
#  'quora_fasttext_meta85',
#  'quora_fasttext_meta86',
#  'quora_fasttext_meta87',
#  'quora_fasttext_meta88',
#  'quora_fasttext_meta89',
#  'quora_fasttext_meta90',
#  'quora_fasttext_meta91',
#  'quora_fasttext_meta92',
#  'quora_fasttext_meta93',
#  'quora_fasttext_meta94',
#  'quora_fasttext_meta95',
#  'quora_fasttext_meta96',
#  'quora_fasttext_meta97',
#  'quora_fasttext_meta98',
#  'quora_fasttext_meta99',
#  'quora_fasttext_meta100',
#  'quora_fasttext_meta101',
#  'quora_fasttext_meta102',
#  'quora_fasttext_meta103',
#  'quora_fasttext_meta104',
#  'quora_fasttext_meta105',
#  'quora_fasttext_meta106',
#  'quora_fasttext_meta107',
#  'quora_fasttext_meta108',
#  'quora_fasttext_meta109',
#  'quora_fasttext_meta110',
#  'quora_fasttext_meta111',
#  'quora_fasttext_meta112',
#  'quora_fasttext_meta113',
#  'quora_fasttext_meta114',
#  'quora_fasttext_meta115',
#  'quora_fasttext_meta116',
#  'quora_fasttext_meta117',
#  'quora_fasttext_meta118',
#  'quora_fasttext_meta119',
#  'quora_fasttext_meta120',
#  'quora_fasttext_meta121',
#  'quora_fasttext_meta122',
#  'quora_fasttext_meta123',
#  'quora_fasttext_meta124',
#  'quora_fasttext_meta125',
#  'quora_fasttext_meta126',
#  'quora_fasttext_meta127',
#  'quora_fasttext_meta128',
#  'quora_fasttext_meta129',
#  'quora_fasttext_meta130',
#  'quora_fasttext_meta131',
#  'quora_fasttext_meta132',
#  'quora_fasttext_meta133',
#  'quora_fasttext_meta134',
#  'quora_fasttext_meta135',
#  'quora_fasttext_meta136',
#  'quora_fasttext_meta137',
#  'quora_fasttext_meta138',
#  'quora_fasttext_meta139',
#  'quora_fasttext_meta140',
#  'quora_fasttext_meta141',
#  'quora_fasttext_meta142',
#  'quora_fasttext_meta143',
#  'quora_fasttext_meta144',
#  'quora_fasttext_meta145',
#  'quora_fasttext_meta146',
#  'quora_fasttext_meta147',
#  'quora_fasttext_meta148',
#  'quora_fasttext_meta149',
#  'quora_fasttext_meta150',
#  'quora_fasttext_meta151',
#  'quora_fasttext_meta152',
#  'quora_fasttext_meta153',
#  'quora_fasttext_meta154',
#  'quora_fasttext_meta155',
#  'quora_fasttext_meta156',
#  'quora_fasttext_meta157',
#  'quora_fasttext_meta158',
#  'quora_fasttext_meta159',
#  'quora_fasttext_meta160',
#  'quora_fasttext_meta161',
#  'quora_fasttext_meta162',
#  'quora_fasttext_meta163',
#  'quora_fasttext_meta164',
#  'quora_fasttext_meta165',
#  'quora_fasttext_meta166',
#  'quora_fasttext_meta167',
#  'quora_fasttext_meta168',
#  'quora_fasttext_meta169',
#  'quora_fasttext_meta170',
#  'quora_fasttext_meta171',
#  'quora_fasttext_meta172',
#  'quora_fasttext_meta173',
#  'quora_fasttext_meta174',
#  'quora_fasttext_meta175',
#  'quora_fasttext_meta176',
#  'quora_fasttext_meta177',
#  'quora_fasttext_meta178',
#  'quora_fasttext_meta179',
#  'quora_fasttext_meta180',
#  'quora_fasttext_meta181',
#  'quora_fasttext_meta182',
#  'quora_fasttext_meta183',
#  'quora_fasttext_meta184',
#  'quora_fasttext_meta185',
#  'quora_fasttext_meta186',
#  'quora_fasttext_meta187',
#  'quora_fasttext_meta188',
#  'quora_fasttext_meta189',
#  'quora_fasttext_meta190',
#  'quora_fasttext_meta191',
#  'quora_fasttext_meta192',
#  'quora_fasttext_meta193',
#  'quora_fasttext_meta194',
#  'quora_fasttext_meta195',
#  'quora_fasttext_meta196',
#  'quora_fasttext_meta197',
#  'quora_fasttext_meta198',
#  'quora_fasttext_meta199',
#  'quora_fasttext_meta200',
#  'quora_fasttext_meta201',
#  'quora_fasttext_meta202',
#  'quora_fasttext_meta203',
#  'quora_fasttext_meta204',
#  'quora_fasttext_meta205',
#  'quora_fasttext_meta206',
#  'quora_fasttext_meta207',
#  'quora_fasttext_meta208',
#  'quora_fasttext_meta209',
#  'quora_fasttext_meta210',
#  'quora_fasttext_meta211',
#  'quora_fasttext_meta212',
#  'quora_fasttext_meta213',
#  'quora_fasttext_meta214',
#  'quora_fasttext_meta215',
#  'quora_fasttext_meta216',
#  'quora_fasttext_meta217',
#  'quora_fasttext_meta218',
#  'quora_fasttext_meta219',
#  'quora_fasttext_meta220',
#  'quora_fasttext_meta221',
#  'quora_fasttext_meta222',
#  'quora_fasttext_meta223',
#  'quora_fasttext_meta224',
#  'quora_fasttext_meta225',
#  'quora_fasttext_meta226',
#  'quora_fasttext_meta227',
#  'quora_fasttext_meta228',
#  'quora_fasttext_meta229',
#  'quora_fasttext_meta230',
#  'quora_fasttext_meta231',
#  'quora_fasttext_meta232',
#  'quora_fasttext_meta233',
#  'quora_fasttext_meta234',
#  'quora_fasttext_meta235',
#  'quora_fasttext_meta236',
#  'quora_fasttext_meta237',
#  'quora_fasttext_meta238',
#  'quora_fasttext_meta239',
#  'quora_fasttext_meta240',
#  'quora_fasttext_meta241',
#  'quora_fasttext_meta242',
#  'quora_fasttext_meta243',
#  'quora_fasttext_meta244',
#  'quora_fasttext_meta245',
#  'quora_fasttext_meta246',
#  'quora_fasttext_meta247',
#  'quora_fasttext_meta248',
#  'quora_fasttext_meta249',
#  'quora_fasttext_meta250',
#  'quora_fasttext_meta251',
#  'quora_fasttext_meta252',
#  'quora_fasttext_meta253',
#  'quora_fasttext_meta254',
#  'quora_fasttext_meta255',
#  'quora_fasttext_meta256',
#  'quora_fasttext_meta257',
#  'quora_fasttext_meta258',
#  'quora_fasttext_meta259',
#  'quora_fasttext_meta260',
#  'quora_fasttext_meta261',
#  'quora_fasttext_meta262',
#  'quora_fasttext_meta263',
#  'quora_fasttext_meta264',
#  'quora_fasttext_meta265',
#  'quora_fasttext_meta266',
#  'quora_fasttext_meta267',
#  'quora_fasttext_meta268',
#  'quora_fasttext_meta269',
#  'quora_fasttext_meta270',
#  'quora_fasttext_meta271',
#  'quora_fasttext_meta272',
#  'quora_fasttext_meta273',
#  'quora_fasttext_meta274',
#  'quora_fasttext_meta275',
#  'quora_fasttext_meta276',
#  'quora_fasttext_meta277',
#  'quora_fasttext_meta278',
#  'quora_fasttext_meta279',
#  'quora_fasttext_meta280',
#  'quora_fasttext_meta281',
#  'quora_fasttext_meta282',
#  'quora_fasttext_meta283',
#  'quora_fasttext_meta284',
#  'quora_fasttext_meta285',
#  'quora_fasttext_meta286',
#  'quora_fasttext_meta287',
#  'quora_fasttext_meta288',
#  'quora_fasttext_meta289',
#  'quora_fasttext_meta290',
#  'quora_fasttext_meta291',
#  'quora_fasttext_meta292',
#  'quora_fasttext_meta293',
#  'quora_fasttext_meta294',
#  'quora_fasttext_meta295',
#  'quora_fasttext_meta296',
#  'quora_fasttext_meta297',
#  'quora_fasttext_meta298',
#  'quora_fasttext_meta299',
#  'quora_fasttext_meta300',
#  'inception_resnet_0',
#  'inception_resnet_1',
#  'inception_resnet_2',
#  'inception_resnet_3',
#  'inception_resnet_4',
#  'inception_resnet_5',
#  'inception_resnet_6',
#  'inception_resnet_7',
#  'inception_resnet_8',
#  'inception_resnet_9',
#  'inception_resnet_10',
#  'inception_resnet_11',
#  'inception_resnet_12',
#  'inception_resnet_13',
#  'inception_resnet_14',
#  'inception_resnet_15',
#  'inception_resnet_16',
#  'inception_resnet_17',
#  'inception_resnet_18',
#  'inception_resnet_19',
#  'inception_resnet_20',
#  'inception_resnet_21',
#  'inception_resnet_22',
#  'inception_resnet_23',
#  'inception_resnet_24',
#  'inception_resnet_25',
#  'inception_resnet_26',
#  'inception_resnet_27',
#  'inception_resnet_28',
#  'inception_resnet_29',
#  'inception_resnet_30',
#  'inception_resnet_31',
#  'inception_resnet_32',
#  'inception_resnet_33',
#  'inception_resnet_34',
#  'inception_resnet_35',
#  'inception_resnet_36',
#  'inception_resnet_37',
#  'inception_resnet_38',
#  'inception_resnet_39',
#  'inception_resnet_40',
#  'inception_resnet_41',
#  'inception_resnet_42',
#  'inception_resnet_43',
#  'inception_resnet_44',
#  'inception_resnet_45',
#  'inception_resnet_46',
#  'inception_resnet_47',
#  'inception_resnet_48',
#  'inception_resnet_49',
#  'inception_resnet_50',
#  'inception_resnet_51',
#  'inception_resnet_52',
#  'inception_resnet_53',
#  'inception_resnet_54',
#  'inception_resnet_55',
#  'inception_resnet_56',
#  'inception_resnet_57',
#  'inception_resnet_58',
#  'inception_resnet_59',
#  'inception_resnet_60',
#  'inception_resnet_61',
#  'inception_resnet_62',
#  'inception_resnet_63',
#  'inception_resnet_64',
#  'inception_resnet_65',
#  'inception_resnet_66',
#  'inception_resnet_67',
#  'inception_resnet_68',
#  'inception_resnet_69',
#  'inception_resnet_70',
#  'inception_resnet_71',
#  'inception_resnet_72',
#  'inception_resnet_73',
#  'inception_resnet_74',
#  'inception_resnet_75',
#  'inception_resnet_76',
#  'inception_resnet_77',
#  'inception_resnet_78',
#  'inception_resnet_79',
#  'inception_resnet_80',
#  'inception_resnet_81',
#  'inception_resnet_82',
#  'inception_resnet_83',
#  'inception_resnet_84',
#  'inception_resnet_85',
#  'inception_resnet_86',
#  'inception_resnet_87',
#  'inception_resnet_88',
#  'inception_resnet_89',
#  'inception_resnet_90',
#  'inception_resnet_91',
#  'inception_resnet_92',
#  'inception_resnet_93',
#  'inception_resnet_94',
#  'inception_resnet_95',
#  'inception_resnet_96',
#  'inception_resnet_97',
#  'inception_resnet_98',
#  'inception_resnet_99',
#  'inception_resnet_100',
#  'inception_resnet_101',
#  'inception_resnet_102',
#  'inception_resnet_103',
#  'inception_resnet_104',
#  'inception_resnet_105',
#  'inception_resnet_106',
#  'inception_resnet_107',
#  'inception_resnet_108',
#  'inception_resnet_109',
#  'inception_resnet_110',
#  'inception_resnet_111',
#  'inception_resnet_112',
#  'inception_resnet_113',
#  'inception_resnet_114',
#  'inception_resnet_115',
#  'inception_resnet_116',
#  'inception_resnet_117',
#  'inception_resnet_118',
#  'inception_resnet_119',
#  'inception_resnet_120',
#  'inception_resnet_121',
#  'inception_resnet_122',
#  'inception_resnet_123',
#  'inception_resnet_124',
#  'inception_resnet_125',
#  'inception_resnet_126',
#  'inception_resnet_127',
#  'inception_resnet_128',
#  'inception_resnet_129',
#  'inception_resnet_130',
#  'inception_resnet_131',
#  'inception_resnet_132',
#  'inception_resnet_133',
#  'inception_resnet_134',
#  'inception_resnet_135',
#  'inception_resnet_136',
#  'inception_resnet_137',
#  'inception_resnet_138',
#  'inception_resnet_139',
#  'inception_resnet_140',
#  'inception_resnet_141',
#  'inception_resnet_142',
#  'inception_resnet_143',
#  'inception_resnet_144',
#  'inception_resnet_145',
#  'inception_resnet_146',
#  'inception_resnet_147',
#  'inception_resnet_148',
#  'inception_resnet_149',
#  'inception_resnet_150',
#  'inception_resnet_151',
#  'inception_resnet_152',
#  'inception_resnet_153',
#  'inception_resnet_154',
#  'inception_resnet_155',
#  'inception_resnet_156',
#  'inception_resnet_157',
#  'inception_resnet_158',
#  'inception_resnet_159',
#  'inception_resnet_160',
#  'inception_resnet_161',
#  'inception_resnet_162',
#  'inception_resnet_163',
#  'inception_resnet_164',
#  'inception_resnet_165',
#  'inception_resnet_166',
#  'inception_resnet_167',
#  'inception_resnet_168',
#  'inception_resnet_169',
#  'inception_resnet_170',
#  'inception_resnet_171',
#  'inception_resnet_172',
#  'inception_resnet_173',
#  'inception_resnet_174',
#  'inception_resnet_175',
#  'inception_resnet_176',
#  'inception_resnet_177',
#  'inception_resnet_178',
#  'inception_resnet_179',
#  'inception_resnet_180',
#  'inception_resnet_181',
#  'inception_resnet_182',
#  'inception_resnet_183',
#  'inception_resnet_184',
#  'inception_resnet_185',
#  'inception_resnet_186',
#  'inception_resnet_187',
#  'inception_resnet_188',
#  'inception_resnet_189',
#  'inception_resnet_190',
#  'inception_resnet_191',
#  'inception_resnet_192',
#  'inception_resnet_193',
#  'inception_resnet_194',
#  'inception_resnet_195',
#  'inception_resnet_196',
#  'inception_resnet_197',
#  'inception_resnet_198',
#  'inception_resnet_199',
#  'inception_resnet_200',
#  'inception_resnet_201',
#  'inception_resnet_202',
#  'inception_resnet_203',
#  'inception_resnet_204',
#  'inception_resnet_205',
#  'inception_resnet_206',
#  'inception_resnet_207',
#  'inception_resnet_208',
#  'inception_resnet_209',
#  'inception_resnet_210',
#  'inception_resnet_211',
#  'inception_resnet_212',
#  'inception_resnet_213',
#  'inception_resnet_214',
#  'inception_resnet_215',
#  'inception_resnet_216',
#  'inception_resnet_217',
#  'inception_resnet_218',
#  'inception_resnet_219',
#  'inception_resnet_220',
#  'inception_resnet_221',
#  'inception_resnet_222',
#  'inception_resnet_223',
#  'inception_resnet_224',
#  'inception_resnet_225',
#  'inception_resnet_226',
#  'inception_resnet_227',
#  'inception_resnet_228',
#  'inception_resnet_229',
#  'inception_resnet_230',
#  'inception_resnet_231',
#  'inception_resnet_232',
#  'inception_resnet_233',
#  'inception_resnet_234',
#  'inception_resnet_235',
#  'inception_resnet_236',
#  'inception_resnet_237',
#  'inception_resnet_238',
#  'inception_resnet_239',
#  'inception_resnet_240',
#  'inception_resnet_241',
#  'inception_resnet_242',
#  'inception_resnet_243',
#  'inception_resnet_244',
#  'inception_resnet_245',
#  'inception_resnet_246',
#  'inception_resnet_247',
#  'inception_resnet_248',
#  'inception_resnet_249',
#  'inception_resnet_250',
#  'inception_resnet_251',
#  'inception_resnet_252',
#  'inception_resnet_253',
#  'inception_resnet_254',
#  'inception_resnet_255',
#  'inception_resnet_256',
#  'inception_resnet_257',
#  'inception_resnet_258',
#  'inception_resnet_259',
#  'inception_resnet_260',
#  'inception_resnet_261',
#  'inception_resnet_262',
#  'inception_resnet_263',
#  'inception_resnet_264',
#  'inception_resnet_265',
#  'inception_resnet_266',
#  'inception_resnet_267',
#  'inception_resnet_268',
#  'inception_resnet_269',
#  'inception_resnet_270',
#  'inception_resnet_271',
#  'inception_resnet_272',
#  'inception_resnet_273',
#  'inception_resnet_274',
#  'inception_resnet_275',
#  'inception_resnet_276',
#  'inception_resnet_277',
#  'inception_resnet_278',
#  'inception_resnet_279',
#  'inception_resnet_280',
#  'inception_resnet_281',
#  'inception_resnet_282',
#  'inception_resnet_283',
#  'inception_resnet_284',
#  'inception_resnet_285',
#  'inception_resnet_286',
#  'inception_resnet_287',
#  'inception_resnet_288',
#  'inception_resnet_289',
#  'inception_resnet_290',
#  'inception_resnet_291',
#  'inception_resnet_292',
#  'inception_resnet_293',
#  'inception_resnet_294',
#  'inception_resnet_295',
#  'inception_resnet_296',
#  'inception_resnet_297',
#  'inception_resnet_298',
#  'inception_resnet_299',
#  'inception_resnet_300',
#  'inception_resnet_301',
#  'inception_resnet_302',
#  'inception_resnet_303',
#  'inception_resnet_304',
#  'inception_resnet_305',
#  'inception_resnet_306',
#  'inception_resnet_307',
#  'inception_resnet_308',
#  'inception_resnet_309',
#  'inception_resnet_310',
#  'inception_resnet_311',
#  'inception_resnet_312',
#  'inception_resnet_313',
#  'inception_resnet_314',
#  'inception_resnet_315',
#  'inception_resnet_316',
#  'inception_resnet_317',
#  'inception_resnet_318',
#  'inception_resnet_319',
#  'inception_resnet_320',
#  'inception_resnet_321',
#  'inception_resnet_322',
#  'inception_resnet_323',
#  'inception_resnet_324',
#  'inception_resnet_325',
#  'inception_resnet_326',
#  'inception_resnet_327',
#  'inception_resnet_328',
#  'inception_resnet_329',
#  'inception_resnet_330',
#  'inception_resnet_331',
#  'inception_resnet_332',
#  'inception_resnet_333',
#  'inception_resnet_334',
#  'inception_resnet_335',
#  'inception_resnet_336',
#  'inception_resnet_337',
#  'inception_resnet_338',
#  'inception_resnet_339',
#  'inception_resnet_340',
#  'inception_resnet_341',
#  'inception_resnet_342',
#  'inception_resnet_343',
#  'inception_resnet_344',
#  'inception_resnet_345',
#  'inception_resnet_346',
#  'inception_resnet_347',
#  'inception_resnet_348',
#  'inception_resnet_349',
#  'inception_resnet_350',
#  'inception_resnet_351',
#  'inception_resnet_352',
#  'inception_resnet_353',
#  'inception_resnet_354',
#  'inception_resnet_355',
#  'inception_resnet_356',
#  'inception_resnet_357',
#  'inception_resnet_358',
#  'inception_resnet_359',
#  'inception_resnet_360',
#  'inception_resnet_361',
#  'inception_resnet_362',
#  'inception_resnet_363',
#  'inception_resnet_364',
#  'inception_resnet_365',
#  'inception_resnet_366',
#  'inception_resnet_367',
#  'inception_resnet_368',
#  'inception_resnet_369',
#  'inception_resnet_370',
#  'inception_resnet_371',
#  'inception_resnet_372',
#  'inception_resnet_373',
#  'inception_resnet_374',
#  'inception_resnet_375',
#  'inception_resnet_376',
#  'inception_resnet_377',
#  'inception_resnet_378',
#  'inception_resnet_379',
#  'inception_resnet_380',
#  'inception_resnet_381',
#  'inception_resnet_382',
#  'inception_resnet_383']

# %%
test.head()
# Out:
#    Type_main_breed  Dewormed  Vaccinated  Sterilized  Color1  Breed1  Color3  \
# 0                1         0           0           0       0       2       0
# 1                0         2           2           2       1       3       0
# 2                0         2           2           2       5       3       0
# 3                0         2           2           2       0       3       1
# 4                1         2           2           2       0       2       1
#
#    Health  Gender  Type          ...           inception_resnet_374  \
# 0       0       0     1          ...                       0.097559
# 1       0       0     0          ...                       0.204406
# 2       0       1     0          ...                       0.257428
# 3       0       1     0          ...                       0.725568
# 4       0       1     1          ...                       0.704487
#
#    inception_resnet_375  inception_resnet_376  inception_resnet_377  \
# 0              0.882323              0.433614              0.531246
# 1              0.603608              0.237417              0.619326
# 2              0.896163              0.403790              0.658857
# 3              1.015948              0.831551              0.972851
# 4              0.406451              0.122368              0.601945
#
#    inception_resnet_378  inception_resnet_379  inception_resnet_380  \
# 0              0.394046              0.351997              0.384253
# 1              0.410897              0.452400              0.480897
# 2              0.350290              0.569676              1.180959
# 3              1.011253              1.225860              1.103978
# 4              0.288864              0.346162              0.289420
#
#    inception_resnet_381  inception_resnet_382  inception_resnet_383
# 0              0.446535              0.247519              0.384539
# 1              0.651550              0.178983              0.754294
# 2              0.806619              0.187933              0.466329
# 3              1.073923              0.564953              0.824841
# 4              0.162718              0.347290              0.651095
#
# [5 rows x 4523 columns]

# %%
# %%time
use_cols = pd.read_csv("importance3.csv")
predictors = list(use_cols[use_cols.gain>0].feature.values) + add_cols
predictors = [c for c in predictors if "gnvec" not in c and "glove_mag" not in c and "img_" not in c]
categorical_features = list(set(categorical_features) - set(remove))
categorical_features = [c for c in categorical_features if c in predictors]
numerical_features = list(set(predictors) - set(categorical_features + [target] + remove))
train = train.loc[:, ~train.columns.duplicated()]

X = train.loc[:, predictors]
X_test = test.loc[:, predictors]
y =  feather.read_dataframe('../input/X_train.feather')["AdoptionSpeed"].values
rescuer_id = pd.read_csv('../input/petfinder-adoption-prediction/train/train.csv').loc[:, 'RescuerID'].iloc[:len_train]

y_pred = np.empty(len_train,)
y_test = np.zeros(len(X_test))

#cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1337)
#for fold_id, (train_index, valid_index) in enumerate(cv.split(range(len(X)), y)):
#cv = GroupKFold(n_splits=n_splits)
#for fold_id, (train_index, valid_index) in enumerate(cv.split(range(len(X)), y=None, groups=rescuer_id)): 
cv = StratifiedGroupKFold(n_splits=n_splits)
for fold_id, (train_index, valid_index) in enumerate(cv.split(range(len(X)), y=y, groups=rescuer_id)): 
    X_train = X.loc[train_index, :]
    X_valid = X.loc[valid_index, :]
    y_train = y[train_index]
    y_valid = y[valid_index]

    y_pred_valid, y_pred_test = run_model(X_train, y_train, X_valid, y_valid, X_test, 
                     categorical_features, numerical_features,
                     predictors, maxvalue_dict, fold_id)
    y_pred_valid = rankdata(y_pred_valid)/len(y_pred_valid)
    y_pred[valid_index] = y_pred_valid.ravel()
    
    y_pred_test = rankdata(y_pred_test)/len(y_pred_test)
    y_test += y_pred_test / n_splits

optR = OptimizedRounder()
optR.fit(y_pred, y)
coefficients = optR.coefficients()
y_pred_opt = optR.predict(y_pred, coefficients)
score = get_score(y, y_pred_opt)
print(score)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [739]	valid's rmse: 1.01912
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [624]	valid's rmse: 1.07076
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [985]	valid's rmse: 1.04889
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [835]	valid's rmse: 1.03352
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [579]	valid's rmse: 1.04294
# 0.4462189809117385
# CPU times: user 1h 19min 22s, sys: 5.51 s, total: 1h 19min 27s
# Wall time: 5min 29s

# %%
np.save("npy/y_oof_inception_gn_light_meta.npy", y_pred)
np.save("npy/y_test_inception_gn_light_meta.npy", y_test)

# %%
X_test.head()
# Out:
#    ratio_median_Age_groupby_Type_Breed1_Breed2  \
# 0                                     0.666667
# 1                                     8.000000
# 2                                     6.666667
# 3                                     1.000000
# 4                                     2.000000
#
#    ratio_median_Age_groupby_Type_Breed1  BreedName_main_breed  crop_y_max  \
# 0                              0.666667                     2       399.0
# 1                              8.000000                     3       240.0
# 2                              6.666667                     3       299.0
# 3                              1.666667                     3       424.0
# 4                              2.000000                     2       479.0
#
#    diff_var_Sterilized_groupby_RescuerID_State  annots_score_sum_median  \
# 0                                     0.766793                 7.749418
# 1                                    -1.233207                 7.752999
# 2                                    -1.233207                 7.853079
# 3                                    -1.233207                 7.407107
# 4                                    -1.233207                 5.592001
#
#    Age_mul_Quantity  diff_mean_Fee_groupby_Type_Breed1_Breed2  \
# 0                 2                               -139.449874
# 1                24                                  8.703365
# 2                20                               -141.296635
# 3                 5                                -60.000000
# 4                 6                               -139.449874
#
#    ratio_count_Quantity_groupby_RescuerID  median_Age_groupby_RescuerID_State  \
# 0                                0.006849                                12.0
# 1                                0.006849                                12.0
# 2                                0.006849                                12.0
# 3                                0.006849                                12.0
# 4                                0.006849                                12.0
#
#            ...           inception_resnet_374  inception_resnet_375  \
# 0          ...                       0.097559              0.882323
# 1          ...                       0.204406              0.603608
# 2          ...                       0.257428              0.896163
# 3          ...                       0.725568              1.015948
# 4          ...                       0.704487              0.406451
#
#    inception_resnet_376  inception_resnet_377  inception_resnet_378  \
# 0              0.433614              0.531246              0.394046
# 1              0.237417              0.619326              0.410897
# 2              0.403790              0.658857              0.350290
# 3              0.831551              0.972851              1.011253
# 4              0.122368              0.601945              0.288864
#
#    inception_resnet_379  inception_resnet_380  inception_resnet_381  \
# 0              0.351997              0.384253              0.446535
# 1              0.452400              0.480897              0.651550
# 2              0.569676              1.180959              0.806619
# 3              1.225860              1.103978              1.073923
# 4              0.346162              0.289420              0.162718
#
#    inception_resnet_382  inception_resnet_383
# 0              0.247519              0.384539
# 1              0.178983              0.754294
# 2              0.187933              0.466329
# 3              0.564953              0.824841
# 4              0.347290              0.651095
#
# [5 rows x 2113 columns]
